# %%
# import libraries
import pandas as pd

# %%
# connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load olist_customers_dataset file
df = pd.read_csv('/content/drive/MyDrive/olist-ecommerce-analytics/processed_csv/olist_customers_dataset.csv')

# %%
# data validation and inspection of the "olist_customers_dataset" file

summary = pd.DataFrame({
    "column": df.columns,
    "dtype": df.dtypes.values,
    "null_count": df.isnull().sum().values,
})

print(summary)
print('\n')

print(f"duplicate_customer_id: {df['customer_id'].duplicated().sum()}")
print(f"unique_customer_id: {df['customer_id'].nunique()}")

print(f"duplicate_customer_unique_id: {df['customer_unique_id'].duplicated().sum()}")
print(f"unique_customer_unique_id: {df['customer_unique_id'].nunique()}")

print('\n')

print(f"unique_customer_zip_code_prefix: {df['customer_zip_code_prefix'].nunique()}")
print(f"unique_customer_city: {df['customer_city'].nunique()}")
print(f"unique_customer_state: {df['customer_state'].nunique()}")
print(f"customer_state: {df['customer_state'].unique()}")
# Out:
#                      column   dtype  null_count
# 0               customer_id  object           0
# 1        customer_unique_id  object           0
# 2  customer_zip_code_prefix   int64           0
# 3             customer_city  object           0
# 4            customer_state  object           0
#
#
# duplicate_customer_id: 0
# unique_customer_id: 99441
# duplicate_customer_unique_id: 3345
# unique_customer_unique_id: 96096
#
#
# unique_customer_zip_code_prefix: 14994
# unique_customer_city: 4119
# unique_customer_state: 27
# customer_state: ['SP' 'SC' 'MG' 'PR' 'RJ' 'RS' 'PA' 'GO' 'ES' 'BA' 'MA' 'MS' 'CE' 'DF'
#  'RN' 'PE' 'MT' 'AM' 'AP' 'AL' 'RO' 'PB' 'TO' 'PI' 'AC' 'SE' 'RR']
